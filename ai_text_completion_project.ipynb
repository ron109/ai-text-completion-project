# %%
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Your prompt here
prompt = "Write a haiku about clouds."

# Generate text
output = generator(prompt, max_length=100, num_return_sequences=1)

# Display result
print("\nAI Response:\n" + output[0]["generated_text"].strip())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Your prompt here
prompt = "Explain gravity like im in 5th grade."

# Generate text
output = generator(prompt, max_length=100, num_return_sequences=1)

# Display result
print("\nAI Response:\n" + output[0]["generated_text"].strip())
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# AI Response:
# Explain gravity like im in 5th grade.
#
# 6) When you hit a big ball roll with your fist, move down until you meet the edge of the ball. This should cause gravity like im in 5th grade.
#
#
# (a) Make sure you land at the center of the ball immediately after hitting the center of the ball with your fist. Be sure that your fist hits the center of your target before you go to the center of the ball. To find the center of

# %%
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Your prompt here
prompt = "Continue this story of the rat and the mouse on a bridge"

# Generate text
output = generator(prompt, max_length=100, num_return_sequences=1)

# Display result
print("\nAI Response:\n" + output[0]["generated_text"].strip())
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# AI Response:
# Continue this story of the rat and the mouse on a bridge between Manhattan and the Bronx and see if you can spot a rat and the mouse on a bridge near Wicker Park.
#
# The rodent was caught around 9 p.m. Wednesday after it came to rest on an elevated railroad bridge, the New York Post reports. Animal control said no animals were brought to the scene. No rats were used in the wild.
#
# "I guess it made sense as that person was running away,

# %%
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Your prompt here
prompt = "Once upon a time, there was a robot who..."

# Generate text
output = generator(prompt, max_length=100, num_return_sequences=1)

# Display result
print("\nAI Response:\n" + output[0]["generated_text"].strip())
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# AI Response:
# Once upon a time, there was a robot who... had a robot-thing. The whole point was that they wanted to use the robot they had developed to help with their work.
#
# But the one person they had left behind had already told them that he wanted the robot to help, and he had told them not to ask the guy as long as he brought it with. So, the robot told them that since he had become a part of some mysterious, benevolent machine, even a robot

# %%
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Your prompt here
prompt = "Write a story about john and his wife Sarah"

# Generate text
output = generator(prompt, max_length=100, num_return_sequences=1)

# Display result
print("\nAI Response:\n" + output[0]["generated_text"].strip())
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# AI Response:
# Write a story about john and his wife Sarah.
#
# "I'd like to know if people think this was the work of an artist or just happen to be in an art gallery?"
#
# The following month, she turned into a serial killer, killing her own daughter with his bare hands.
#
# "A lot of people know me pretty well, but I've never been on a suicide note," she says about her story.
#
# She's been at St Paul Post-Gaz
